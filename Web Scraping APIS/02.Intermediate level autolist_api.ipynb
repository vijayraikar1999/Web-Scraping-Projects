# %%
import requests
import pandas as pd

# %%
import requests

response = requests.get('https://www.autolist.com/api/cwv/seo/listings?make=Tesla&location=San%20Francisco,%20CA&latitude=37.7749295&longitude=-122.4194155&radius=50&page=1')

# %%
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
results_json = response.json()

# %%
results_json
# Out:
# {'total_results_count': 514,
#  'make_model_name': 'Tesla',
#  'trims': [],
#  'ad_info': {'ad_unit': '/19485787/AutoList.com/Search_Results_Page/Tesla',
#   'make': 'Tesla',
#   'model': None,
#   'page_type': 'srp',
#   'cpo': False,
#   'body_style': None,
#   'year': 2023,
#   'age_type': 'new',
#   'app': 'web',
#   'seller_id': None,
#   'content_url': 'https://www.autolist.com/listings#latitude=37.7749295&location=San+Francisco%2C+CA&longitude=-122.4194155&make=Tesla&page=1&radius=50'},
#  'search_results': [{'available_nationwide': False,
#    'created_at': 1655514800,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJXCAE2XHF051959',
#    'vdp_url': '/tesla-model+x#vin=5YJXCAE2XHF051959',
#    'clickoff_url': 'https://www.shift.com/car/c1141634?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 245257464,
# ...

# %%
results_json.keys()
# Out:
# dict_keys(['total_results_count', 'make_model_name', 'trims', 'ad_info', 'search_results', 'html'])

# %%
# model
# mileage
# year
# dealer name
# price

# %%
results = results_json['search_results']

# %%
results
# Out:
# [{'available_nationwide': False,
#   'created_at': 1655514800,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/5YJXCAE2XHF051959',
#   'vdp_url': '/tesla-model+x#vin=5YJXCAE2XHF051959',
#   'clickoff_url': 'https://www.shift.com/car/c1141634?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 245257464,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/06/23/02/56/2017_tesla_model_x-pic-556834372418005368-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--OJIU00Qu--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/06/23/02/56/2017_tesla_model_x-pic-556834372418005368-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2017,
#   'make': 'Tesla',
#   'model': 'Model X',
#   'model_id': 2101,
#   'display_color': '',
#   'price': '$71,950',
#   'price_unformatted': 71950,
# ...

# %%
len(results)
# Out:
# 20

# %%
results[0]
# Out:
# {'available_nationwide': False,
#  'created_at': 1655514800,
#  'recent_price_drop': None,
#  'is_hot': False,
#  'href_target': '/listings/5YJXCAE2XHF051959',
#  'vdp_url': '/tesla-model+x#vin=5YJXCAE2XHF051959',
#  'clickoff_url': 'https://www.shift.com/car/c1141634?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#  'accepts_leads': True,
#  'open_in_new_window': False,
#  'id': 245257464,
#  'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/06/23/02/56/2017_tesla_model_x-pic-556834372418005368-1024x768.jpeg',
#  'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--OJIU00Qu--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/06/23/02/56/2017_tesla_model_x-pic-556834372418005368-1024x768.jpeg',
#  'lat': 37.6397,
#  'lon': -122.416,
#  'year': 2017,
#  'make': 'Tesla',
#  'model': 'Model X',
#  'model_id': 2101,
#  'display_color': '',
#  'price': '$71,950',
#  'price_unformatted': 71950,
# ...

# %%
results[0]['model']
# Out:
# 'Model X'

# %%
model = []
mileage = []
year = []
dealer_name = []
price = []

# %%
i = 1
while i < 6:
    response = requests.get(f'https://www.autolist.com/api/cwv/seo/listings?make=Tesla&location=San%20Francisco,%20CA&latitude=37.7749295&longitude=-122.4194155&radius=50&page={i}')
    if response.status_code == 200:
        print(response.status_code)
        results_json = response.json()
        results = results_json['search_results']
        for result in results:
            # model
            model.append(result['model'])

            # mileage
            mileage.append(result['mileage'])

            # year
            year.append(result['year'])

            # dealer_name
            dealer_name.append(result['dealer_name'])

            # price
            price.append(result['price'])
    i += 1
# Out:
# 200
# 200
# 200
# 200
# 200

# %%
tesla_cars_df = pd.DataFrame(
    {
     'Model': model,
     'Mileage': mileage,
     'year': year,
     'dealer_name': dealer_name,
     'Price': price,
    }
)

# %%
tesla_cars_df.head()
# Out:
#      Model       Mileage  year                              dealer_name  \
# 0  Model X  41,257 Miles  2017  Shift SF - Test Drives Delivered To You
# 1  Model 3  13,286 Miles  2019  Shift SF - Test Drives Delivered To You
# 2  Model 3  54,274 Miles  2019  Shift SF - Test Drives Delivered To You
# 3  Model 3  24,394 Miles  2019  Shift SF - Test Drives Delivered To You
# 4  Model 3  53,078 Miles  2018  Shift SF - Test Drives Delivered To You
#
#      Price
# 0  $71,950
# 1  $55,950
# 2  $44,450
# 3  $48,450
# 4  $46,950

# %%
tesla_cars_df.to_csv('tesla_cars.csv', index=False)
